# %%
#from dotenv import load_dotenv
import guidance
import os

#load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")
endpoint = os.getenv("OPENAI_ENDPOINT")
llm = guidance.models.AzureOpenAI(
    model="gpt-35-turbo",
    azure_endpoint=endpoint,
    api_key = api_key,
    version="1106",
    max_streaming_tokens=999,
    )

# %%
from typing import Dict, Tuple, List

sea_ice_variables = [
    "geopotential_heights", 
    "relative_humidity", 
    "sea_level_pressure",  
    "zonal_wind_at_10_meters", 
    "meridional_wind_at_10_meters", 
    "sensible_plus_latent_heat_flux", 
    "total_precipitation", 
    "total_cloud_cover", 
    "total_cloud_water_path",  
    "surface_net_shortwave_flux", 
    "surface_net_longwave_flux", 
    "northern_hemisphere_sea_ice_extent",
]

treatment = "surface_net_longwave_flux"
outcome = "northern_hemisphere_sea_ice_extent"

# ground truth confounders to the relationship between surface_net_longwave_flux and northern_hemisphere_sea_ice_extent
sea_ice_confounders = ["total_precipitation"]
   
sea_ice_relationships: List[Tuple[str, str]] = [
    ("surface_net_longwave_flux", "northern_hemisphere_sea_ice_extent"), 
    
    ("geopotential_heights", "surface_net_longwave_flux"), 
    ("geopotential_heights", "relative_humidity"), 
    ("geopotential_heights", "sea_level_pressure"), 

    ("relative_humidity", "total_cloud_cover"), 
    ("relative_humidity", "total_cloud_water_path"),
    ("relative_humidity", "total_precipitation"), 
    ("relative_humidity", "surface_net_longwave_flux"),

    ("sea_level_pressure", "relative_humidity"), 
    ("sea_level_pressure", "geopotential_heights"), 
    ("sea_level_pressure", "zonal_wind_at_10_meters"), 
    ("sea_level_pressure", "northern_hemisphere_sea_ice_extent"), 
    ("sea_level_pressure", "sensible_plus_latent_heat_flux"), 
    ("sea_level_pressure", "meridional_wind_at_10_meters"),

    ("zonal_wind_at_10_meters", "northern_hemisphere_sea_ice_extent"),
    ("zonal_wind_at_10_meters", "sensible_plus_latent_heat_flux"), 
    
    ("meridional_wind_at_10_meters", "northern_hemisphere_sea_ice_extent"),
    ("meridional_wind_at_10_meters", "sensible_plus_latent_heat_flux"), 
   
    ("sensible_plus_latent_heat_flux", "northern_hemisphere_sea_ice_extent"), 
    ("sensible_plus_latent_heat_flux", "sea_level_pressure"), 
    ("sensible_plus_latent_heat_flux", "zonal_wind_at_10_meters"), 
    ("sensible_plus_latent_heat_flux", "meridional_wind_at_10_meters"), 
    ("sensible_plus_latent_heat_flux", "total_precipitation"), 
    ("sensible_plus_latent_heat_flux", "total_cloud_cover"), 
    ("sensible_plus_latent_heat_flux", "total_cloud_water_path"), 
    
    ("total_precipitation", "northern_hemisphere_sea_ice_extent"),
    ("total_precipitation", "relative_humidity"),
    ("total_precipitation", "sensible_plus_latent_heat_flux"),
    ("total_precipitation", "surface_net_longwave_flux"),
    ("total_precipitation", "total_cloud_cover"),
    ("total_precipitation", "total_cloud_water_path"),
   
    ("total_cloud_water_path", "total_precipitation"), 
    ("total_cloud_water_path", "sensible_plus_latent_heat_flux"), 
    ("total_cloud_water_path", "relative_humidity"), 
    ("total_cloud_water_path", "surface_net_longwave_flux"), 
    ("total_cloud_water_path", "surface_net_shortwave_flux"), 
    
    ("total_cloud_cover", "total_precipitation"),
    ("total_cloud_cover", "sensible_plus_latent_heat_flux"),
    ("total_cloud_cover", "relative_humidity"),
    ("total_cloud_cover", "surface_net_longwave_flux"),
    ("total_cloud_cover", "surface_net_shortwave_flux"), 
    
    ("surface_net_shortwave_flux", "northern_hemisphere_sea_ice_extent"),
    
    ("northern_hemisphere_sea_ice_extent", "sea_level_pressure"),
    ("northern_hemisphere_sea_ice_extent", "zonal_wind_at_10_meters"),
    ("northern_hemisphere_sea_ice_extent", "meridional_wind_at_10_meters"),
    ("northern_hemisphere_sea_ice_extent", "sensible_plus_latent_heat_flux"),
    ("northern_hemisphere_sea_ice_extent", "surface_net_shortwave_flux"),
    ("northern_hemisphere_sea_ice_extent", "surface_net_longwave_flux"),
]

# %% [markdown]
# ## Helpers

# %% [markdown]
# Model type - the type of LLM used
# By default it's set to completions models

# %% [markdown]
# Relationship strategy - is the type of request made to the LLM (request parent, child, pairwise relationship)

# %% [markdown]
# ## Model

# %%
import pywhyllm
m = pywhyllm.SimpleModelSuggester()

"""returns a dictionary with the how many times that edge was suggested"""
model_edges = m.suggest_pairwise_relationship(llm, treatment, outcome)
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2);  justify-content: center; align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>You are a helpful assistant for causal reasoning.</div></div><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2);  justify-content: center; align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>user</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>
#             Which cause-and-effect-relationship is more likely?
#             A. surface_net_longwave_flux causes northern_hemisphere_sea_ice_extent
#             B. northern_hemisphere_sea_ice_extent causes surface_net_longwave_flux
#             C. neither surface_net_longwave_flux nor northern_hemisphere_sea_ice_extent cause each other
#             First let&#x27;s very succinctly think about each option.
#             Then I&#x27;ll ask you to provide your final answer A, B, or C.</div></div><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2);  justify-content: center; align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>assistant</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>Let</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>&#x27;s</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> consider</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> each</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> option</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>:
#
# </span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>A</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>.</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> **</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>Surface</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> Net</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> Long</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>wave</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> Flux</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> Causes</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> Northern</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> Hemisphere</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> Sea</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> Ice</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> Ext</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>ent</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>**:</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>
# </span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>   </span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>-</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> **</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>Surface</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> net</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> long</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>wave</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> flux</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>**</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> refers</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> to</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> the</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> net</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> amount</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> of</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> long</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>wave</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> radiation</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> (</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>heat</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>)</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> that</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> is</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> emitted</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> and</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> absorbed</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> by</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> the</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> Earth</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>&#x27;s</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> surface</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>.</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> An</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> increase</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> in</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> this</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> flux</span><span style='background-color: rgba(0.0, 165.0, 0, 0.

# %%
"""returns a dictionary with how many times a confounder/edge with confounder was suggested"""
"""suggest_relationships calls suggest_confounders"""
relationships = m.suggest_relationships(llm, sea_ice_variables[:2])
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2);  justify-content: center; align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>You are a helpful assistant for causal reasoning.</div></div><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2);  justify-content: center; align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>user</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>
#             Which cause-and-effect-relationship is more likely?
#             A. geopotential_heights causes relative_humidity
#             B. relative_humidity causes geopotential_heights
#             C. neither geopotential_heights nor relative_humidity cause each other
#             First let&#x27;s very succinctly think about each option.
#             Then I&#x27;ll ask you to provide your final answer A, B, or C.</div></div><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2);  justify-content: center; align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>assistant</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>To</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> evaluate</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> the</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> cause</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>-and</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>-effect</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> relationship</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> between</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> geo</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>potential</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> heights</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> and</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> relative</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> humidity</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>,</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> let</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>&#x27;s</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> briefly</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> consider</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> each</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> option</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>:
#
# </span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>A</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>.</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> **</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>Geo</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>potential</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> Heights</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> causes</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> Relative</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> Hum</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>idity</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>**:</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> Geo</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>potential</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> height</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> is</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> a</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> measure</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> used</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> in</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> meteor</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>ology</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> to</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> indicate</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> the</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> altitude</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> at</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> which</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> a</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> given</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> pressure</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> is</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> found</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> in</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> the</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> atmosphere</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>.</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> Changes</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> in</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-
# 	geopotential_heights causes relative_humidity

# %%
confounders = m.suggest_confounders(llm, variables=sea_ice_variables, treatment=treatment, outcome=outcome)
# Out:
# <pre style='margin: 0px; padding: 0px; vertical-align: middle; padding-left: 8px; margin-left: -8px; border-radius: 0px; border-left: 1px solid rgba(127, 127, 127, 0.2); white-space: pre-wrap; font-family: ColfaxAI, Arial; font-size: 15px; line-height: 23px;'><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2);  justify-content: center; align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>system</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>You are a helpful assistant for causal reasoning.</div></div><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2);  justify-content: center; align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>user</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'>
#          What latent confounding factors might influence the relationship between surface_net_longwave_flux and northern_hemisphere_sea_ice_extent?
#
#         We have already considered the following factors [&#x27;geopotential_heights&#x27;, &#x27;relative_humidity&#x27;, &#x27;sea_level_pressure&#x27;, &#x27;zonal_wind_at_10_meters&#x27;, &#x27;meridional_wind_at_10_meters&#x27;, &#x27;sensible_plus_latent_heat_flux&#x27;, &#x27;total_precipitation&#x27;, &#x27;total_cloud_cover&#x27;, &#x27;total_cloud_water_path&#x27;, &#x27;surface_net_shortwave_flux&#x27;, &#x27;surface_net_longwave_flux&#x27;, &#x27;northern_hemisphere_sea_ice_extent&#x27;].  Please do not repeat them.
#
#         List the confounding factors between surface_net_longwave_flux and northern_hemisphere_sea_ice_extent enclosing the name of each factor in &lt;conf&gt; &lt;/conf&gt; tags.</div></div><div style='display: flex; border-bottom: 1px solid rgba(127, 127, 127, 0.2);  justify-content: center; align-items: center;'><div style='flex: 0 0 80px; opacity: 0.5;'>assistant</div><div style='flex-grow: 1; padding: 5px; padding-top: 10px; padding-bottom: 10px; margin-top: 0px; white-space: pre-wrap; margin-bottom: 0px;'><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>Certainly</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>!</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> When</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> considering</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> latent</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> conf</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>ounding</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> factors</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> that</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> might</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> influence</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> the</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> relationship</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> between</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> </span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>&lt;conf</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>&gt;s</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>urface</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>_net</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>_long</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>wave</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>_flux</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>&lt;/</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>conf</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>&gt;</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> and</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'> </span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>&lt;conf</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>&gt;n</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>orth</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>ern</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>_he</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-radius: 3px;' title='1.0'>mis</span><span style='background-color: rgba(0.0, 165.0, 0, 0.15); border-ra ...

# %%
confounders
# Out:
# ['surface_net_longwave_flux',
#  'northern_hemisphere_sea_ice_extent',
#  'ocean_currents',
#  'atmospheric_aerosol_concentrations',
#  'solar_radiation',
#  'volcanic_activity',
#  'greenhouse_gas_concentrations',
#  'ocean_salinity']

# %% [markdown]
# ## Identifier

# %%
from pywhyllm.identification_suggester import IdentificationSuggester
i = IdentificationSuggester()

"""calls modeler suggest_confounders in the background"""
backdoor = i.suggest_backdoor(treatment=treatment, outcome=outcome, factors_list=sea_ice_variables, llm=llm)

"""suggests mediators"""
front_door = i.suggest_frontdoor(treatment=treatment, outcome=outcome, factors_list=sea_ice_variables, llm=llm)

"""suggests instrumental variables"""
ivs = i.suggest_ivs(treatment=treatment, outcome=outcome, factors_list=sea_ice_variables, llm=llm)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       2 i = IdentificationSuggester()
#       4 """calls modeler suggest_confounders in the background"""
# ----> 5 backdoor = i.suggest_backdoor(treatment=treatment, outcome=outcome, factors_list=sea_ice_variables, llm=llm)
#       7 """suggests mediators"""
#       8 front_door = i.suggest_frontdoor(treatment=treatment, outcome=outcome, factors_list=sea_ice_variables, llm=llm)
#
# File ~/reference/pywhy-llm/pywhyllm/identification_suggester.py:130, in IdentificationSuggester.suggest_backdoor(self, treatment, outcome, factors_list, llm, experts, analysis_context, stakeholders, temperature, model_type)
#     118 def suggest_backdoor(
#     119     self,
#     120     treatment: str,
#    (...)
#     128     model_type: ModelType = ModelType.Completion,
#     129 ):
# --> 130     backdoor_set = self.model_suggester.suggest_confounders(
#     131         analysis_context=analysis_context,
#     132         treatment=treatment,
#     133         outcome=outcome,
#     134         factors_list=factors_list,
#     135         experts=experts,
#     136         llm=llm,
#     137         stakeholders=stakeholders,
#     138         temperature=temperature,
#     139         model_type=model_type,
#     140     )
#     141     return backdoor_set
#
# File ~/reference/pywhy-llm/pywhyllm/model_suggester.py:165, in ModelSuggester.suggest_confounders(self, treatment, outcome, factors_list, llm, experts, analysis_context, stakeholders, temperature, model_type)
#     162     for elements in stakeholders:
#     163         expert_list.append(elements)
# --> 165 suggest = guidance(ps[model_type.value]["expert_suggests_confounders"])
#     167 confounders_edges: Dict[Tuple[str, str], int] = dict()
#     168 confounders_edges[(treatment, outcome)] = 1
#
# File ~/reference/pywhy-llm/.venv/lib/python3.9/site-packages/guidance/__init__.py:26, in _Guidance.__call__(self, f, stateless, cache, dedent, model)
#      23 def __call__(
#      24     self, f=None, *, stateless=False, cache=None, dedent=True, model=models.Model
#      25 ):
# ---> 26     return _decorator(
#      27         f, stateless=stateless, cache=cache, dedent=dedent, model=model
#      28     )
#
# File ~/reference/pywhy-llm/.venv/lib/python3.9/site-packages/guidance/_guidance.py:29, in _decorator(f, stateless, cache, dedent, model)
#      24 # if we are being used as a decorator then return the decorated function
#      25 else:
#      26
#      27     # this strips out indentation in multiline strings that aligns with the current python indentation
#      28     if dedent is True or dedent == "python":
# ---> 29         f = strip_multiline_string_indents(f)
#      31     # we cache if requested
#      32     if cache:
#
# File ~/reference/pywhy-llm/.venv/lib/python3.9/site-packages/guidance/_utils.py:75, in strip_multiline_string_indents(f)
#      74 def strip_multiline_string_indents(f):
# ---> 75     source = textwrap.dedent(inspect.getsource(f))
#      76     blanks = "\n" * f.__code__.co_firstlineno  # pad the source so the lines in the file line up for the debugger
#      77     source = blanks + "\n".join(source.splitlines()[1:])  # remove the decorator first line.
#
# File /usr/lib/python3.9/inspect.py:1024, in getsource(object)
#    1018 def getsource(object):
#    1019     """Return the text of the source code for an object.
#    1020
#    1021     The argument may be a module, class, method, function, traceback, frame,
#    1022     or code object.  The source code is returned as a single string.  An
#    1023     OSError is raised if the source code cannot be retrieved."""
# -> 1024     lines, lnum = getsourcelines(object)
#    1025     return ''.join(lines)
#
# File /usr/lib/python3.9/inspect.py:1006, in getsourcelines(object)
#     998 """Return a list of source lines and starting line number for an object.
#     999
#    1000 The argument may be a module, class, method, function, traceback, frame,
#    (...)
#    1003 original source file the first line of code was found.  An OSError is
#    1004 raised if the source code cannot be retrieved."""
#    1005 object = unwrap(object)
# -> 1006 lines, lnum = findsource(object)
#    1008 if istraceback(object):
#    1009     object = object.tb_frame
#
# File /usr/lib/python3.9/inspect.py:817, in findsource(object)
#     809 def findsource(object):
#     810     """Return the entire source file and starting line number for an object.
#     811
#     812     The argument may be a module, class, method, function, traceback, frame,
#     813     or code object.  The source code is returned as a list of all the lines
#     814     in the file and the line number indexes a line in that list.  An OSError
#     815     is raised if the source code cannot be retrieved."""
# --> 817     file = getsourcefile(object)
#     818     if file:
#     819         # Invalidate cache if needed.
#     820         linecache.checkcache(file)
#
# File /usr/lib/python3.9/inspect.py:697, in getsourcefile(object)
#     693 def getsourcefile(object):
#     694     """Return the filename that can be used to locate an object's source.
#     695     Return None if no way can be identified to get the source.
#     696     """
# --> 697     filename = getfile(object)
#     698     all_bytecode_suffixes = importlib.machinery.DEBUG_BYTECODE_SUFFIXES[:]
#     699     all_bytecode_suffixes += importlib.machinery.OPTIMIZED_BYTECODE_SUFFIXES[:]
#
# File /usr/lib/python3.9/inspect.py:677, in getfile(object)
#     675 if iscode(object):
#     676     return object.co_filename
# --> 677 raise TypeError('module, class, method, function, traceback, frame, or '
#     678                 'code object was expected, got {}'.format(
#     679                 type(object).__name__))
#
# TypeError: module, class, method, function, traceback, frame, or code object was expected, got str

# %% [markdown]
# ## Validator

# %%
from pywhyllm.helpers import RelationshipStrategy
from pywhyllm.validation_suggester import ValidationSuggester
v = ValidationSuggester()

"""suggets latent confounders"""
latent_confounders = v.suggest_latent_confounders(treatment=treatment, outcome=outcome, factors_list=sea_ice_variables, llm=llm)

"""suggests negative controls"""
negative_controls = v.suggest_negative_controls(treatment=treatment, outcome=outcome, factors_list=sea_ice_variables, llm=llm)

parent=RelationshipStrategy.Parent
child=RelationshipStrategy.Child
pairwise=RelationshipStrategy.Pairwise

"""Relationship strategy for choosing how to get the model critiqued"""
edges, critiqued_edges = v.critique_graph(edges=model_edges, treatment=treatment, outcome=outcome, factors_list=sea_ice_variables, llm=llm, relationship_strategy=parent)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 from pywhyllm.helpers import RelationshipStrategy
# ----> 2 from pywhyllm.validation_suggester import ValidationSuggester
#       3 v = ValidationSuggester()
#       5 """suggets latent confounders"""
#
# File ~/reference/pywhy-llm/pywhyllm/validation_suggester.py:11
#       7 import copy
#       8 import re
# ---> 11 class ValidationSuggester(IdentifierProtocol):
#      12     EXPERTS: list() = [
#      13         "causality, you are an intelligent AI with expertise in causality",
#      14         "answering questions about causality, you are a helpful causality assistant ",
#      15     ]
#      16     CONTEXT: str = """causal mechanisms"""
#
# File ~/reference/pywhy-llm/pywhyllm/validation_suggester.py:23, in ValidationSuggester()
#      12 EXPERTS: list() = [
#      13     "causality, you are an intelligent AI with expertise in causality",
#      14     "answering questions about causality, you are a helpful causality assistant ",
#      15 ]
#      16 CONTEXT: str = """causal mechanisms"""
#      18 def suggest_negative_controls(
#      19     self,
#      20     treatment: str,
#      21     outcome: str,
#      22     factors_list: list(),
# ---> 23     llm: guidance.llms,
#      24     experts: list() = EXPERTS,
#      25     analysis_context: list() = CONTEXT,
#      26     stakeholders: list() = None,
#      27     temperature=0.3,
#      28     model_type: ModelType = ModelType.Completion,
#      29 ):
#      30     expert_list: List[str] = list()
#      31     for elements in experts:
#
# AttributeError: module 'guidance' has no attribute 'llms'
